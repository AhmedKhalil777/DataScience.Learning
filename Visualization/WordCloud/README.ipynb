# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text = ("Ahmed_Khalil Ahmed_Khalil Ahmed_Khalil Ahmed_Khalil Ahmed_Khalil Ahmed_Khalil Python C# Python C# C# .NetCore .NetCore .NetCore .NetCore Blazor Aspnet Signalr Data_Science Data_Science Microservices Microservices Microservices Microservices Microservices EFCore  Docker Docker Docker Docker Angular Angular Angular MongoDb MongoDb Cosmos Cosmos GraphQL Javascript Django Django Distributed_system Security IOT  WSL2 Selenium NodeJS NodeJS Typescript R R R VS_Code Microsoft Microsoft CIS CIS  ")

# %%
wordcloud = WordCloud(width= 1980 , height= 1220 , margin= 0 ).generate(text)
plt.imshow(wordcloud,interpolation= 'bilinear'  )
plt.axis("off")
plt.margins(x=0,y=0)
plt.show()
